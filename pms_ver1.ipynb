# %% [markdown]
# <a href="https://colab.research.google.com/github/chaos1231107/2025_model_rocket_project/blob/main/pms_ver1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/가천대/동아리 활동/files/'
df = pd.read_excel(path+'pressure.xlsx')
df.dropna(inplace=True)
df
# Out:
#           t    p
# 0     0.103  0.8
# 1     0.205  1.0
# 2     0.307  1.0
# 3     0.409  0.8
# 4     0.511  1.0
# ..      ...  ...
# 716  74.746  1.0
# 717  74.848  1.0
# 718  74.950  1.0
# 719  75.520  1.0
# 720  75.155  1.0
#
# [721 rows x 2 columns]

# %%
plt.plot(df['t'], df['p'], marker='o', linestyle='-')
plt.title("Preasure - Time", fontsize=13, y=1.02)
plt.xlim(54.0, 56.0)
plt.xlabel("Time(s)")
plt.ylabel("Preasure(bar)")
plt.grid(alpha=0.5)
plt.show()
